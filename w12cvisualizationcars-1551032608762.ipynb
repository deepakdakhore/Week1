# %% [markdown]
# 2-plot-cars Lab
# ==================
#
# ### Overview
# - Learn matplotlib library
#
# ### Depends On
# None
#
# ### Run time
# 15-20 mins

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Cars Dataset
#
# The "cars" dataset has speed and stopping distance of different cars. Each line is a different observation.

# %%
cars = pd.read_csv('https://s3.amazonaws.com/elephantscale-public/data/cars/cars.csv')
cars
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %% [markdown]
# **=> Plot a matplotlib graph to demonstrate the relationship between speed and stopping distance.**
#
# **=> Add title, and labels for X and Y axis.**

# %%
    cars.plot(kind='bar',title ="Relationship between speed & stopping distance")
    plt.xticks(rotation=0)
    plt.xlabel('Speed')
    plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')

# %% [markdown]
# ## Cars93 dataset
#
# **=> Import Cars93 dataset.**

# %%
Cars93 = pd.read_csv('https://s3.amazonaws.com/elephantscale-public/data/cars/cars93.csv')
Cars93
# Out:
#     Unnamed: 0 Manufacturer          Model     Type  Min.Price  Price  \
# 0            1        Acura        Integra    Small       12.9   15.9
# 1            2        Acura         Legend  Midsize       29.2   33.9
# 2            3         Audi             90  Compact       25.9   29.1
# 3            4         Audi            100  Midsize       30.8   37.7
# 4            5          BMW           535i  Midsize       23.7   30.0
# 5            6        Buick        Century  Midsize       14.2   15.7
# 6            7        Buick        LeSabre    Large       19.9   20.8
# 7            8        Buick     Roadmaster    Large       22.6   23.7
# 8            9        Buick        Riviera  Midsize       26.3   26.3
# 9           10     Cadillac        DeVille    Large       33.0   34.7
# 10          11     Cadillac        Seville  Midsize       37.5   40.1
# 11          12    Chevrolet       Cavalier  Compact        8.5   13.4
# 12          13    Chevrolet        Corsica  Compact       11.4   11.4
# 13          14    Chevrolet         Camaro   Sporty       13.4   15.1
# 14          15    Chevrolet         Lumina  Midsize       13.4   15.9
# 15          16    Chevrolet     Lumina_APV      Van       14.7   16.3
# 16          17    Chevrolet          Astro      Van       14.7   16.6
# 17          18    Chevrolet        Caprice    Large       18.0   18.8
# 18          19    Chevrolet       Corvette   Sporty       34.6   38.0
# 19          20     Chrylser       Concorde    Large       18.4   18.4
# 20          21     Chrysler        LeBaron  Compact       14.5   15.8
# 21          22     Chrysler       Imperial    Large       29.5   29.5
# 22          23        Dodge           Colt    Small        7.9    9.2
# 23          24        Dodge         Shadow    Small        8.4   11.3
# 24          25        Dodge         Spirit  Compact       11.9   13.3
# 25          26        Dodge        Caravan      Van       13.6   19.0
# 26          27        Dodge        Dynasty  Midsize       14.8   15.6
# 27          28        Dodge        Stealth   Sporty       18.5   25.8
# 28          29        Eagle         Summit    Small        7.9   12.2
# 29          30        Eagle         Vision    Large       17.5   19.3
# ..         ...          ...            ...      ...        ...    ...
# 63          64       Nissan         Sentra    Small        8.7   11.8
# 64          65       Nissan         Altima  Compact       13.0   15.7
# 65          66       Nissan          Quest      Van       16.7   19.1
# 66          67       Nissan         Maxima  Midsize       21.0   21.5
# 67          68   Oldsmobile        Achieva  Compact       13.0   13.5
# 68          69   Oldsmobile  Cutlass_Ciera  Midsize       14.2   16.3
# 69          70   Oldsmobile     Silhouette      Van       19.5   19.5
# 70          71   Oldsmobile   Eighty-Eight    Large       19.5   20.7
# 71          72     Plymouth          Laser   Sporty       11.4   14.4
# 72          73      Pontiac         LeMans    Small        8.2    9.0
# 73          74      Pontiac        Sunbird  Compact        9.4   11.1
# 74          75      Pontiac       Firebird   Sporty       14.0   17.7
# 75          76      Pontiac     Grand_Prix  Midsize       15.4   18.5
# 76          77      Pontiac     Bonneville    Large       19.4   24.4
# 77          78         Saab            900  Compact       20.3   28.7
# 78          79       Saturn             SL    Small        9.2   11.1
# 79          80       Subaru          Justy    Small        7.3    8.4
# 80          81       Subaru         Loyale    Small       10.5   10.9
# 81          82       Subaru         Legacy  Compact       16.3   19.5
# 82          83       Suzuki          Swift    Small        7.3    8.6
# 83          84       Toyota         Tercel    Small        7.8    9.8
# 84          85       Toyota         Celica   Sporty       14.2   18.4
# 85          86       Toyota          Camry  Midsize       15.2   18.2
# 86          87       Toyota         Previa      Van       18.9   22.7
# 87          88   Volkswagen            Fox    Small        8.7    9.1
# 88          89   Volkswagen        Eurovan      Van       16.6   19.7
# 89          90   Volkswagen         Passat  Compact       17.6   20.0
# 90          91   Volkswagen        Corrado   Sporty       22.9   23.3
# 91          92        Volvo            240  Compact       21.8   22.7
# 92          93        Volvo            850  Midsize       24.8   26.7
#
#     Max.Price  MPG.city  MPG.highway             AirBags  \
# 0        18.8        25           31                None
# 1        38.7        18           25  Driver & Passenger
# 2        32.3        20           26         Driver only
# 3        44.6        19           26  Driver & Passenger
# 4        36.2        22           30         Driver only
# 5        17.3        22           31         Driver only
# 6        21.7        19           28         Driver only
# 7        24.9        16           25         Driver only
# 8        26.3        19           27         Driver only
# 9        36.3        16           25         Driver only
# 10       42.7        16           25  Driver & Passenger
# 11       18.3        25           36                None
# 12       11.4        25           34         Driver only
# 13       16.8        19           28  Driver & Passenger
# 14       18.4        21           29                None
# 15       18.0        18           23                None
# 16       18.6        15           20                None
# 17       19.6        17           26         Driver only
# 18       41.5        17           25         Driver only
# 19       18.4        20           28  Driver & Passenger
# 20       17.1        23           28  Driver & Passenger
# 21       29.5        20           26         Driver only
# 22       10.6        29           33                None
# 23       14.2        23           29         Driver only
# 24       14.7        22           27         Driver only
# 25       24.4        17           21         Driver only
# 26       16.4        21           27         Driver only
# 27       33.1        18           24         Driver only
# 28       16.5        29           33                None
# 29       21.2        20           28  Driver & Passenger
# ..        ...       ...          ...                 ...
# 63       14.9        29           33         Driver only
# 64       18.3        24           30         Driver only
# 65       21.5        17           23                None
# 66       22.0        21           26         Driver only
# 67       14.0        24           31                None
# 68       18.4        23           31         Driver only
# 69       19.5        18           23                None
# 70       21.9        19           28         Driver only
# 71       17.4        23           30                None
# 72        9.9        31           41                None
# 73       12.8        23           31                None
# 74       21.4        19           28  Driver & Passenger
# 75       21.6        19           27                None
# 76       29.4        19           28  Driver & Passenger
# 77       37.1        20           26         Driver only
# 78       12.9        28           38         Driver only
# 79        9.5        33           37                None
# 80       11.3        25           30                None
# 81       22.7        23           30         Driver only
# 82       10.0        39           43                None
# 83       11.8        32           37         Driver only
# 84       22.6        25           32         Driver only
# 85       21.2        22           29         Driver only
# 86       26.6        18           22         Driver only
# 87        9.5        25           33                None
# 88       22.7        17           21                None
# 89       22.4        21           30                None
# 90       23.7        18           25                None
# 91       23.5        21           28         Driver only
# 92       28.5        20           28  Driver & Passenger
#
#               ...            Passengers Length  Wheelbase  Width  Turn.circle  \
# 0             ...                     5    177        102     68           37
# 1             ...                     5    195        115     71           38
# 2             ...                     5    180        102     67           37
# 3             ...                     6    193        106     70           37
# 4             ...                     4    186        109     69           39
# 5             ...                     6    189        105     69           41
# 6             ...                     6    200        111     74           42
# 7             ...                     6    216        116     78           45
# 8             ...                     5    198        108     73           41
# 9             ...                     6    206        114     73           43
# 10            ...                     5    204        111     74           44
# 11            ...                     5    182        101     66           38
# 12            ...                     5    184        103     68           39
# 13            ...                     4    193        101     74           43
# 14            ...                     6    198        108     71           40
# 15            ...                     7    178        110     74           44
# 16            ...                     8    194        111     78           42
# 17            ...                     6    214        116     77           42
# 18            ...                     2    179         96     74           43
# 19            ...                     6    203        113     74           40
# 20            ...                     6    183        104     68           41
# 21            ...                     6    203        110     69           44
# 22            ...                     5    174         98     66           32
# 23            ...                     5    172         97     67           38
# 24            ...                     6    181        104     68           39
# 25            ...                     7    175        112     72           42
# 26            ...                     6    192        105     69           42
# 27            ...                     4    180         97     72           40
# 28            ...                     5    174         98     66           36
# 29            ...                     6    202        113     74           40
# ..            ...                   ...    ...        ...    ...          ...
# 63            ...                     5    170         96     66           33
# 64            ...                     5    181        103     67           40
# 65            ...                     7    190        112     74           41
# 66            ...                     5    188        104     69           41
# 67            ...                     5    188        103     67           39
# 68            ...                     5    190        105     70           42
# 69            ...                     7    194        110     74           44
# 70            ...                     6    201        111     74           42
# 71            ...                     4    173         97     67           39
# 72            ...                     4    177         99     66           35
# 73            ...                     5    181        101     66           39
# 74            ...                     4    196        101     75           43
# 75            ...                     5    195        108     72           41
# 76            ...                     6    177        111     74           43
# 77            ...                     5    184         99     67           37
# 78            ...                     5    176        102     68           40
# 79            ...                     4    146         90     60           32
# 80            ...                     5    175         97     65           35
# 81            ...                     5    179        102     67           37
# 82            ...                     4    161         93     63           34
# 83            ...                     5    162         94     65           36
# 84            ...                     4    174         99     69           39
# 85            ...                     5    188        103     70           38
# 86            ...                     7    187        113     71           41
# 87            ...                     4    163         93     63           34
# 88            ...                     7    187        115     72           38
# 89            ...                     5    180        103     67           35
# 90            ...                     4    159         97     66           36
# 91            ...                     5    190        104     67           37
# 92            ...                     5    184        105     69           38
#
#     Rear.seat.room Luggage.room  Weight   Origin                      Make
# 0             26.5         11.0    2705  non-USA             Acura Integra
# 1             30.0         15.0    3560  non-USA              Acura Legend
# 2             28.0         14.0    3375  non-USA                   Audi 90
# 3             31.0         17.0    3405  non-USA                  Audi 100
# 4             27.0         13.0    3640  non-USA                  BMW 535i
# 5             28.0         16.0    2880      USA             Buick Century
# 6             30.5         17.0    3470      USA             Buick LeSabre
# 7             30.5         21.0    4105      USA          Buick Roadmaster
# 8             26.5         14.0    3495      USA             Buick Riviera
# 9             35.0         18.0    3620      USA          Cadillac DeVille
# 10            31.0         14.0    3935      USA          Cadillac Seville
# 11            25.0         13.0    2490      USA        Chevrolet Cavalier
# 12            26.0         14.0    2785      USA         Chevrolet Corsica
# 13            25.0         13.0    3240      USA          Chevrolet Camaro
# 14            28.5         16.0    3195      USA          Chevrolet Lumina
# 15            30.5          NaN    3715      USA      Chevrolet Lumina_APV
# 16            33.5          NaN    4025      USA           Chevrolet Astro
# 17            29.5         20.0    3910      USA         Chevrolet Caprice
# 18             NaN          NaN    3380      USA        Chevrolet Corvette
# 19            31.0         15.0    3515      USA         Chrylser Concorde
# 20            30.5         14.0    3085      USA          Chrysler LeBaron
# 21            36.0         17.0    3570      USA         Chrysler Imperial
# 22            26.5         11.0    2270      USA                Dodge Colt
# 23            26.5         13.0    2670      USA              Dodge Shadow
# 24            30.5         14.0    2970      USA              Dodge Spirit
# 25            26.5          NaN    3705      USA             Dodge Caravan
# 26            30.5         16.0    3080      USA             Dodge Dynasty
# 27            20.0         11.0    3805      USA             Dodge Stealth
# 28            26.5         11.0    2295      USA              Eagle Summit
# 29            30.0         15.0    3490      USA              Eagle Vision
# ..             ...          ...     ...      ...                       ...
# 63            26.0         12.0    2545  non-USA             Nissan Sentra
# 64            28.5         14.0    3050  non-USA             Nissan Altima
# 65            27.0          NaN    4100  non-USA              Nissan Quest
# 66            28.5         14.0    3200  non-USA             Nissan Maxima
# 67            28.0         14.0    2910      USA        Oldsmobile Achieva
# 68            28.0         16.0    2890      USA  Oldsmobile Cutlass_Ciera
# 69            30.5          NaN    3715      USA     Oldsmobile Silhouette
# 70            31.5         17.0    3470      USA   Oldsmobile Eighty-Eight
# 71            24.5          8.0    2640      USA            Plymouth Laser
# 72            25.5         17.0    2350      USA            Pontiac LeMans
# 73            25.0         13.0    2575      USA           Pontiac Sunbird
# 74            25.0         13.0    3240      USA          Pontiac Firebird
# 75            28.5         16.0    3450      USA        Pontiac Grand_Prix
# 76            30.5         18.0    3495      USA        Pontiac Bonneville
# 77            26.5         14.0    2775  non-USA                  Saab 900
# 78            26.5         12.0    2495      USA                 Saturn SL
# 79            23.5         10.0    2045  non-USA              Subaru Justy
# 80            27.5         15.0    2490  non-USA             Subaru Loyale
# 81            27.0         14.0    3085  non-USA             Subaru Legacy
# 82            27.5         10.0    1965  non-USA              Suzuki Swift
# 83            24.0         11.0    2055  non-USA             Toyota Tercel
# 84            23.0         13.0    2950  non-USA             Toyota Celica
# 85            28.5         15.0    3030  non-USA              Toyota Camry
# 86            35.0          NaN    3785  non-USA             Toyota Previa
# 87            26.0         10.0    2240  non-USA            Volkswagen Fox
# 88            34.0          NaN    3960  non-USA        Volkswagen Eurovan
# 89            31.5         14.0    2985  non-USA         Volkswagen Passat
# 90            26.0         15.0    2810  non-USA        Volkswagen Corrado
# 91            29.5         14.0    2985  non-USA                 Volvo 240
# 92            30.0         15.0    3245  non-USA                 Volvo 850
#
# [93 rows x 28 columns]

# %% [markdown]
# **=> Calculate average MPG.city for each car type.**

# %%
Cars93['MPG.avg'] = (Cars93['MPG.city'] + Cars93['MPG.highway']) / 2

## Calculate avg MPG for each type
m = Cars93.groupby('Type').agg({'MPG.avg': 'mean'}) 
m
# Out:
#            MPG.avg
# Type
# Compact  26.281250
# Large    22.545455
# Midsize  23.136364
# Small    32.666667
# Sporty   25.285714
# Van      19.444444

# %% [markdown]
# **=> Do a matplotlib barplot on car Type vs average mileage.**

# %%
# TODO: Do a bar plot
barplot = m.plot(kind='bar',title="Average Mileage")
barplot

# %% [markdown]
# **=> Add colors to the graph!**
#
# Hint: set the color parameter on the pyplot bar. It is a list of the colors you want. ['yellow', 'maroon']

# %%
# TODO: Add Colors
barplot = m.plot(kind='bar', color =['maroon'], title="Average Mileage")
barplot

# %% [markdown]
# ### Boxplot
# **=> BoxPlot  Car type vs MPG.**

# %%
# TODO: Perform Boxplot
barplot = m.plot(kind='box')
barplot

# %% [markdown]
# ### Histograms
#
# **=> Do a histogram on car prices.**

# %%
# TODO: Perform Histogram
x = Cars93['Price']
plt.hist(x, 5, normed=1, facecolor='green', alpha=0.75)
plt.xlabel('Car')
plt.ylabel('Price')
plt.title('Car Price')
plt.axis([1, 70, 0, 0.06])
plt.grid(True)

plt.show()

# %% [markdown]
# **=> Do a discrete histogram for car types.**
# Note: `hist`  works well with continuous values.
# Hint: use pandas df.value_counts function to calculate frequencies, then plot.

# %%
# TODO: Hisogram of car types
x = Cars93['Type'].value_counts()
plt.hist(x, 5, normed=1, facecolor='green', alpha=0.75)
plt.xlabel('Car')
plt.ylabel('Price')
plt.title('Car Price')
plt.axis([1, 40, 0, 0.15])
plt.grid(True)

plt.show()

# %% [markdown]
# ### Hmmm... Pie!
# **=> Do a pie-chart on  US vs non-US models**

# %%
# Do a pie chart.
x = Cars93['Origin'].value_counts()
labels=['US','Non-US']
explode = (0, 0)
colors = ['Red', 'yellow']
plt.pie(x, explode=explode, labels=labels, colors=colors)
plt.axis('equal')
plt.show()
plt.savefig('books_read.png')

# %% [markdown]
# ### Save Graphs
# And finally export a graph into a file (pdf or png)
#
# you can use plt.savefig()

# %%
# Save graph.
plt.savefig('books_read.png')

# %% [markdown]
# ### Scatter Plot Matrix
#
# How do we plot in more than 2 or 3 dimensions?
#
# Use a scatter plot matrix?

# %%
trees = pd.read_csv('https://s3.amazonaws.com/elephantscale-public/data/trees/trees.csv')
trees
# Out:
#     Girth  Height  Volume
# 0     8.3      70    10.3
# 1     8.6      65    10.3
# 2     8.8      63    10.2
# 3    10.5      72    16.4
# 4    10.7      81    18.8
# 5    10.8      83    19.7
# 6    11.0      66    15.6
# 7    11.0      75    18.2
# 8    11.1      80    22.6
# 9    11.2      75    19.9
# 10   11.3      79    24.2
# 11   11.4      76    21.0
# 12   11.4      76    21.4
# 13   11.7      69    21.3
# 14   12.0      75    19.1
# 15   12.9      74    22.2
# 16   12.9      85    33.8
# 17   13.3      86    27.4
# 18   13.7      71    25.7
# 19   13.8      64    24.9
# 20   14.0      78    34.5
# 21   14.2      80    31.7
# 22   14.5      74    36.3
# 23   16.0      72    38.3
# 24   16.3      77    42.6
# 25   17.3      81    55.4
# 26   17.5      82    55.7
# 27   17.9      80    58.3
# 28   18.0      80    51.5
# 29   18.0      80    51.0
# 30   20.6      87    77.0

# %%
import seaborn as sns
sns.set(style="ticks")

sns.pairplot(trees)

# %% [markdown]
# **=> Do you spot any relation between Girth, Height and Volume?**
#
# **=> Plot those two attributes in a separate graph.**
